# %% [markdown]
# Write a Python program to replace all occurrences of a space, comma, or dot with a colon.
# Sample Text- 'Python Exercises, PHP exercises.'

# %%
import re

# %%
text = 'Python Exercises, PHP exercises.'

# %%
print(re.sub("[ ,.]", ":", text))
# Out:
# Python:Exercises::PHP:exercises:

# %% [markdown]
# Create a dataframe using the dictionary below and remove everything (commas (,), !, XXXX, ;, etc.) from the columns except words.
# Dictionary- {'SUMMARY' : ['hello, world!', 'XXXXX test', '123four, five:; six...']}

# %%
import pandas as pd
import re

# %%
data_dict = {'SUMMARY':['hello, world!','XXXXX test', '123four, five:; six...']}

# %%
df = pd.DataFrame(data_dict)

# %%
df['SUMMARY'] = df['SUMMARY'].apply(lambda x: re.sub(r'[^a-zA-Z\s]', '', x))

# %%
print(df)
# Out:
#          SUMMARY
# 0    hello world
# 1     XXXXX test
# 2  four five six

# %% [markdown]
# Create a function in python to find all words that are at least 4 characters long in a string. The use of the re.compile() method is mandatory.

# %%
import re

# %%
def find_long_words(text):
    pattern = re.compile(r'\b\w{4,}\b')
    long_words = pattern.findall(text)
    return long_words

# %%
text = "This is a great way to work in a better way."
result = find_long_words(text)
print("words with at least 4 characters")
print(result)
# Out:
# words with at least 4 characters
# ['This', 'great', 'work', 'better']

# %% [markdown]
# Create a function in python to find all three, four, and five character words in a string. The use of the re.compile() method is mandatory.

# %%
import re

def find_word_length(string):
    pattern = re.compile(r'\b\w{3,5}\b')
    string_length = pattern.findall(string)
    return string_length

# %%
string = "This should for sure work this time abcde."
result = find_word_length(string)
print("Word with 3, 4 and 5 characters")
print(result)
# Out:
# Word with 3, 4 and 5 characters
# ['This', 'for', 'sure', 'work', 'this', 'time', 'abcde']

# %%
def find_word_length(letter):
    pattern = re.compile(r'\b\w{3,4,5}\b')
    word_length = pattern.findall(letter)
    return word_length
letter = "I am sure this will work this time."
result = find_word_length(letter)
print(Words with 3, 4 and 5 characters")
print(result)
result = find_word_length(letter)
print(Words with 3,4 and5 characters")
print(result)
result = find_word_length(letter)
print(Words with 3 and 5 characters")
print(result)
result = find_word_length(letter)
print("Words with 3, 4 and 5 characters")
print(result)
letter = "I am sure this will work this time."
result = find_word_length(letter)
print("Words with 3,4 and 5 characters")
print(result)
letter = "I am sure this will work this time."
result = find_word_length(letter)
print("Words with 3,4 and 5 characters")
print(result)
letter = "I am sure this will work this time."
result = find_word_length(letter)
print("Words with 3,4 and 5 characters")
print(result)
letter = "I am sure this will work this time."
result = find_word_length(letter)
print("Words with 3,4 and 5 characters")
print(result)
letter = "I am sure this will work this time."
result = find_word_length(letter)
print("Words with 3,4 and 5 characters")
print(result)
letter = "I am sure this will work this time."
result = find_word_length(letter)
print("Words with 3,4 and 5 characters")
print(result)
string = "I am sure this will work this time."
result = find_word_length(string)
print("Words with 3,4 and 5 characters")
print(result)
import re

def find_word_length(string):
    pattern = re.compile(r'\b\w{3,4,5}\b')
    string_length = pattern.findall(string)
    return string_length
import re

def find_word_length(string):
    pattern = re.compile(r'\b\w{3,5}\b')
    string_length = pattern.findall(string)
    return string_length
string = "This should for sure work this time abcde."
result = find_word_length(string)
print("Word with 3, 4 and 5 characters")
print(result)
string = "This should for sure work this time abcde."
result = find_word_length(string)
print("Word with 3, 4 and 5 characters")
print(result)
import re

def remove_parenthesis(strings):
    pattern = re.compile(r'\([^]*\)')
    result = [pattern.sub('', string) for string in strings]
    return result
Sample_Text = ["example (.com)", "hr@fliprobo (.com)", "github (.com)", "Hello (Data Science World)", "Data (Scientist)"]
result = remove_parenthesis(Sample_Text)
print(result)
strings = ["example (.com)", "hr@fliprobo (.com)", "github (.com)", "Hello (Data Science World)", "Data (Scientist)"]
result = remove_parenthesis(strings)
print(result)
import re

def remove_parentheses(strings):
    pattern = re.compile(r'\([^]*\)')
    result = [pattern.sub('', string) for string in strings]
    return result
strings = ["example (.com)", "hr@fliprobo (.com)", "github (.com)", "Hello (Data Science World)", "Data (Scientist)"]
result = remove_parentheses(strings)
print(result)
string = ["example (.com)", "hr@fliprobo (.com)", "github (.com)", "Hello (Data Science World)", "Data (Scientist)"]
result = remove_parentheses(strings)
print(result)
import re
import re
items = ["example (.com)", "w3resource", "github (.com)", "stackoverflow (.com)"]
for item in items:
    print(re.sub(r" ?\([^)]+\)", "", item))
import re
def remove_parenthesis(text):
    pattern = re.compile(r'\([^)]*\)')
    return pattern.sub('', text)
import re

Sample_text = "ImportanceOfRegularExpressionsInPython"
uppercase_letters = re.findall('[A-Z]', Sample_text)
print(uppercase_letters)
uppercase_letters = re.split(r'(?=[A-Z]', Sample_text)
print(uppercase_letters)
uppercase_letters = re.split(r'(?=[A-Z])', Sample_text)
print(uppercase_letters)
uppercase_letters = re.findall('[A-Z][^A-Z]*', Sample_text)
print(uppercase_letters)
import re
def insert_spaces(text):
    return re.sub(r'(\d)9[A-Za-z])', r'\1 \2', text)
Sample_Text = "RegularExpression1IsAn2ImportantTopic3InPython"
new_text = insert.space(Sample_Text)
print(Sample_Text)
Sample_Text = "RegularExpression1IsAn2ImportantTopic3InPython"
new_text = insert.spaces(Sample_Text)
print(Sample_Text)
def insert_spaces(text):
    pattern = r'([A-Z[a-z0-9]+|\d+])
    result= re.sub(pattern, r'\1', text)
    result = result.strip()
    return result
def insert_spaces(text):
    pattern = r'([A-Z[a-z0-9]+|\d+])'
    result= re.sub(pattern, r'\1', text)
    result = result.strip()
    return result
sample_text = "RegularExpression1IsAn2ImportantTopic3InPython"
new_text = insert_spaces(sample_text)
print(new_text)
def insert_spaces(text):
    pattern = r'([A-Z[a-z0-9]+|\d+])'
    result= re.sub(pattern, r' \1', text)
    result = result.strip()
    return result
sample_text = "RegularExpression1IsAn2ImportantTopic3InPython"
new_text = insert_spaces(sample_text)
print(new_text)
import re
def insert_spaces(text):
    pattern = r'([A-Z][a-z0-9]+|\d+)'
    result = re.sub(pattern, r' \1', text)
    result = result.strip()
sample_text = "RegularExpression1IsAn2ImportantTopic3InPython"
new_text = insert_spaces(sample_text)
print(sample_text)
def insert_spaces(text):
    return re.sub(r'(\b[A-Z\d]\w*)', r' \1', text)
text = "RegularExpression1IsAn2ImportantTopic3InPython"
new_text = insert_spaces(text)
print(new_text)
sample_text = "RegularExpression1IsAn2ImportantTopic3InPython"
new_text = insert_spaces(sample_text)
print(sample_text)
def insert_spaces(sample_text):
    return re.sub(r'(\b[A-Z\d]\w*)', r' \1', sample_text)
sample_text = "RegularExpression1IsAn2ImportantTopic3InPython"
new_text = insert_spaces(sample_text)
print(sample_text)
import pandas as pd
url = "https://raw.githubusercontent.com/dsrscientist/DSData/master/happiness_score_dataset.csv"
df = pd.read_csv(url)
df['first_five_letters'] = df['Country'].str[:6]
print(df.head())
import re
def match_string(text):
    pattern = re.complile(r'^[a-zA-Z0-9_]+$')
    if pattern.match(text):
        return True
    else:
        return False
test_string = ["Hey007", "Lokesh", "Loving_Python", "124_ok", "Tata!"]
for string in test_string:
    print(f"{string}: {match_string(string0)}")
test_string = ["Hey007", "Lokesh", "Loving_Python", "124_ok", "Tata!"]
for string in test_string:
    print(f"{string}: {match_string(string)}")
def match_string(text):
    pattern = r'^[a-zA-Z0-9_]*$'
    if re.search(pattern, text):
        return True
    else:
        return False
print(match_string("I_07 have started to learn python is new_ways"))
print(match_string("Practicing_python_1"))
import re
def starts_with_number(string, number):
    pattern = r'^' + str(number)
    return re.match(pattern, string) is not None
sample_string1 = "5-2345861"
sample_string2 = "6-2345861"
print(starts_with_number(sample_string1, 5))
print(starts_with_number(sample_string2, 5))
import re
def remove_zeros_from_ip(ip_add):
    return re.sub(r'^|\.)0+(?=[^.])', r'\1', ip_add)
ip1 = '198.0.01.10'
ip2 = '198.00.002.20'
print(remove_zeros_from_ip(ip1))
print(remove_zeros_from_ip(ip2))
ip1 = '10.0.01.10'
ip2 = '10.00.002.20'
print(remove_zeros_from_ip(ip1))
print(remove_zeros_from_ip(ip2))
def remove_zeros_from_ip(ip_add):
    return re.sub(r'(^|\.)0+(?=[^.])', r'\1', ip_add)
ip1 = '10.0.01.10'
ip2 = '10.00.002.20'
print(remove_zeros_from_ip(ip1))
print(remove_zeros_from_ip(ip2))
import re
def extract_dates_from_text(text):
    pattern = r'([A-Z][a-z]+) (\d{1,2})(?:st|nd|rd|th)? (\d{4})'
def extract_dates_from_text(text):
    pattern = r'([A-Z][a-z]+) (\d{1,2})(?:st|nd|rd|th)? (\d{4})'
    matches = re.findall(pattern, text)
    new_dates = [f"{month} {day} {year}" for month, day, year in matches]
    return new_dates
Sample_text = "On August 15th 1947 that India was declared independent from British colonialism, and the reins of control were handed over to the leaders of the Country."
dates_in_text = extract_dates_from_text(sample_text)
print("Extracted Dates:")
for date in dates_in_text:
    print(date)
Sample_text = 'On August 15th 1947 that India was declared independent from British colonialism, and the reins of control were handed over to the leaders of the Country.'
dates_in_text = extract_dates_from_text(Sample_text)
print("Extracted Dates:")
for date in dates_in_text:
    print(date)
import re
def search_literals_with_location(text, patterns):
    for pattern in patterns:
        match = re.search(pattern, text)
        if match:
            start_index = match.start()
            end_index = match.end()
            print(f"Found \"{pattern}\" in \"{text}\"")
Sample_text = 'The quick brown fox jumps over the lazy dog.'
searched_words = ['fox', 'dog', 'horse']
search_literals_with_location(Sample_text, searched_words)
import re
def find_pattern_location(text, pattern):
    match = re.search(pattern, text)
    if match:
        start_index = match.start()
        end_index = match.end()
        print(f"Found \"{pattern}\" in \"{text}\"")
sample_text = 'The quick brown fox jumps over the lazy dog.'
sample_text = 'The quick brown fox jumps over the lazy dog.'
searched_word = 'fox'
find_pattern_location(sample_text, searched_word)
def find_substrings(text,pattern):
def find_substrings(text,pattern):
    substrings = text.split(pattern)
    substrings = [s for s in substrings if s]
    return substrings
sample_text = ('Python exercises, PHP exercises, C# exercises')
search_pattern = 'exercises'
found_substring = find_substring(sample_text, search_pattern)
sample_text = ('Python exercises, PHP exercises, C# exercises')
search_pattern = 'exercises'
found_substring = find_substring(sample_text, search_pattern)
print("Found substrings:")
for substring in found_substrings:
    print(substring)
sample_text = ('Python exercises, PHP exercises, C# exercises')
search_pattern = 'exercises'
found_substrings = find_substrings(sample_text, search_pattern)
print("Found substrings:")
for substrings in found_substrings:
    print(substring)
sample_text = ('Python exercises, PHP exercises, C# exercises')
search_pattern = 'exercises'
found_substrings = find_substrings(sample_text, search_pattern)
print("Found substrings:")
for substrings in found_substrings:
    print(substrings)
import re

def find_occurrences_and_positions(text, pattern):
    for match in re.finditer(pattern, text):
        start_index = match.start()
        end_index = match.end()
        found_substring = text[start_index:end_index]
        print(f"Found \"{found_substring}\" at {start_index}:{end_index}")
sample_text = 'Python exercises, PHP exercises, C# exercises'
search_pattern = 'exercises'
find_occurences_and_positions(sample_text, search_pattern)
import re

def find_occurences_and_positions(text, pattern):
    for match in re.finditer(pattern, text):
        start_index = match.start()
        end_index = match.end()
        found_substring = text[start_index:end_index]
        print(f"Found \"{found_substring}\" at {start_index}:{end_index}")
sample_text = 'Python exercises, PHP exercises, C# exercises'
search_pattern = 'exercises'
find_occurences_and_positions(sample_text, search_pattern)
import re

def convert_date_format_regex(date_str):
    pattern = r'(\d{4})-(\d{2})-(\d{2})'
    match = re.match(pattern, date_str)
    if match:
        day, month, year = match.groups()
        formatted_date = f"{day}-{month}-{year}"
        return formatted_date
    else:
        return "Invalid date format. Please provide a valid yyyy-mm-dd date."
import re
def convert_date_format_regex(date_str):
    pattern = r'(\d{4})-(\d{2})-(\d{2})'
    match = re.match(pattern, date_str)
    if match:
        day, month, year = match.groups()
        formatted_date = f"{day}-{month}-{year}"
        return formatted_date
    else:
        return "Invalid date format. Please provide a valid yyyy-mm-dd date."
input_date = "2024-04-06"
output_date = convert_date_format_regex(input_date)
print(f"Converted date: {output_date}")
import re
def find_decimal_numbers(text):
    pattern = re.compile(r'\b\d+\.\d{1,2}\b')
    return pattern.findall(text)
sample_text = "01.12 0132.123 2.31875 145.8 3.01 27.25 0.25"
result = find_decimal_numbers(sample_text)
print(result)
import re
def find_numbers_and_positions(text):
    pattern = re.compile(r'\b\d+\b')
    for match in pattern.finditer(text):
        number = match.group()
        position = match.start()
        print(f"Number: {number}, Position: {position}")
sample_text = "Let us find out what number and position does this example finds after running thsi code after 30 minutes of investment."
find_numbers_and_positions(sample_text)
import re
def extract_max_numeric_value(text):
     numbers = re.findall(r'\d+', text)
        max_number = max(map(int, numbers))
        return max_number
def extract_max_numeric_value(text):
     numbers = re.findall(r'\d+', text)
        max_number = max(map(int, numbers))
        return max_number
def extract_max_numeric_value(text):
     numbers = re.findall(r'\d+', text)
        maximum_number = max(map(int, numbers))
        return maximum_number
def extract_max_numeric_value(text):
     numeric_value = re.findall(r'\d+', text)
        if numeric_value:
            return max(map(int, numeric_values))
        else:
        return None
def extract_maximum_numeric_value(text):
     numeric_value = re.findall(r'\d+', text)
        if numeric_value:
            return max(map(int, numeric_values))
        else:
        return None
import re
def insert_spaces(text):
    pattern = re.compile(r'([A-Z][a-z]+)')
    result = pattern.sub(r' \1', text)
    return result.strip()
sample_text = “RegularExpressionIsAnImportantTopicInPython"
sample_text = “RegularExpressionIsAnImportantTopicInPython"
new_text = insert_spaces(sample_text)
print(new_text)
sample_text = "RegularExpressionIsAnImportantTopicInPython"
new_text = insert_spaces(sample_text)
print(new_text)
import re
def find_sequences(text):
def find_sequences(text):
    pattern = r'[A-Z][a-z]+'
    matches = re.findall(pattern.text)
    return matches
sample_text = "What all matches you are able to find?"
found_sequences = find_sequences(sample_text)
print(found_sequences)
sample_text = "How many matches are you able to find in this string?"
found_sequences = find_sequences(sample_text)
print(found_sequences)
sample_text = "How many matches are you able to find in this string?"
find_sequences = found_sequences(sample_text)
print(find_sequences)
sample_text = "How many matches are you able to find in this string?"
found_sequences = find_sequences(sample_text)
print(found_sequences)
def find_sequences(text):
    pattern = r'[A-Z][a-z]+'
    matches = re.findall(pattern.text)
    return matches
sample_text = "How many matches are you able to find in this string?"
new_sequence = find_sequences(sample_text)
print(new_sequences)
sample_text = "How Many matches Are you Able to Find in This String?"
new_sequence = find_sequences(sample_text)
print(new_sequences)
def find_sequences(text):
    
    text = "How Many matches Are you Able to Find in This String?"
    pattern = re.compile (r'[A-Z][a-z]+')
    matches = pattern.findall(text)
    print(matches)
def find_sequences(text):
    
    text = "How Many matches Are you Able to Find in This String?"
    pattern = re.compile (r'[A-Z][a-z]+')
    matches = pattern.findall(text)
    print(matches)
import re
text = "How Many matches Are you Able to Find in This String?"
pattern = re.compile(r'[A-Z][a-z]+')
matches = pattern.findall(text)
print(matches)
import re
def remove_continuous_duplicate_words(sentence):
    return re.sub(r'\b(w+)(\s+\1)+\b', r'\1', sentence, flags=re.IGNORECASE)
sample_text = "Hello hello world world"
sample_text = "Hello hello world world"
result = remove_continuous_duplicates(sample_text)
print(result)
def remove_continuous_duplicates(sentence):
    return re.sub(r'\b(w+)(\s+\1)+\b', r'\1', sentence, flags=re.IGNORECASE)
sample_text = "Hello hello world world"
result = remove_continuous_duplicates(sample_text)
print(result)
import re
def ends_with_alphanum(text):
    pattern = re.compile(r'^.*[a-zA-Z0-9]$')
    if pattern.match(text):
        return True
    else
    return False
def ends_with_alphanum(text):
    pattern = re.compile(r'^.*[a-zA-Z0-9]$')
    if pattern.match(text):
        return True
    else:
    return False
def ends_with_alphanum(text):
    pattern = re.compile(r'^.*[a-zA-Z0-9]$')
    if pattern.match(text):
        return True
    else:
    return False
def ends_with_alphanum(text):
    pattern = re.compile(r'^.*[a-zA-Z0-9]$')
    if pattern.match(text):
        return True
    else:
        
    return False
def ends_with_alphanum(text):
    pattern = re.compile(r'^.*[a-zA-Z0-9]$')
    if pattern.match(text):
        return True
    else:
        
    return False
def ends_with_alphanum(text):
    pattern = re.compile(r'^.*[a-zA-Z0-9]$')
    if pattern.match(text):
        return True
    
    else:
        
    return False
def ends_with_alphanum(text):
    pattern = re.compile(r'^.*[a-zA-Z0-9]$')
    if pattern.match(text):
        return True
    else:  
    return False
def ends_with_alphanumeric(text):
    pattern = re.compile(r'^.*[a-zA-Z0-9]$')
    if pattern.match(text):
        return True
    else:
        return False
new_string = ["Hey", "Lucky07", "going", "well", "with", "python420_"]
for string in new_string:
    print(f"{string}: {ends_with_alphanumeric(string)}")
import re
def extract_hasgtags(text):
    return re.findall(r'#\w+', text)
Sample_Text = """RT @kapil_kausik: #Doltiwal I mean #xyzabc is "hurt" by #Demonetization as the same has rendered USELESS <U+00A0><U+00BD><U+00B1><U+0089> "acquired funds" No wo"""
hashtags = extract_hastags(Sample_Text)
print(hashtags)
# %history
​
# Out:
# def find_word_length(letter):
#     pattern = re.compile(r'\b\w{3,4,5}\b')
#     word_length = pattern.findall(letter)
#     return word_length
# letter = "I am sure this will work this time."
# result = find_word_length(letter)
# print(Words with 3, 4 and 5 characters")
# print(result)
# result = find_word_length(letter)
# print(Words with 3,4 and5 characters")
# print(result)
# result = find_word_length(letter)
# print(Words with 3 and 5 characters")
# print(result)
# result = find_word_length(letter)
# print("Words with 3, 4 and 5 characters")
# print(result)
# letter = "I am sure this will work this time."
# result = find_word_length(letter)
# print("Words with 3,4 and 5 characters")
# print(result)
# letter = "I am sure this will work this time."
# result = find_word_length(letter)
# print("Words with 3,4 and 5 characters")
# print(result)
# letter = "I am sure this will work this time."
# result = find_word_length(letter)
# print("Words with 3,4 and 5 characters")
# ...

# %% [markdown]
# Write a python program using RegEx to extract the hashtags.
# Sample Text:  """RT @kapil_kausik: #Doltiwal I mean #xyzabc is "hurt" by #Demonetization as the same has rendered USELESS <ed><U+00A0><U+00BD><ed><U+00B1><U+0089> "acquired funds" No wo"""

# %%
import re

# %%
def extract_hashtags(text):
    return re.findall(r'#\w+', text)

# %%
sample_text = """RT @kapil_kaushik: #Doltiwal I mean #xyzabc is "hurt" by #Demonetization as the same has rendered USELESS <U+00A0>U+00BD><U+00B1><U+0089> "acquired funds" No wo"""
hashtags = extract_hashtags(sample_text)
print(hashtags)
# Out:
# ['#Doltiwal', '#xyzabc', '#Demonetization']

# %% [markdown]
# - Write a python program using RegEx to remove <U+..> like symbols
# Check the below sample text, there are strange symbols something of the sort <U+..> all over the place. You need to come up with a general Regex expression that will cover all such symbols.
# Sample Text: "@Jags123456 Bharat band on 28??<ed><U+00A0><U+00BD><ed><U+00B8><U+0082>Those who  are protesting #demonetization  are all different party leaders"
# Expected Output: @Jags123456 Bharat band on 28??<ed><ed>Those who  are protesting #demonetization  are all different party leaders

# %%
import re

# %%
def remove_symbols(text):
    return re.sub(r'<U\+[0-9-Fa-f]+>', '', text)

# %%
sample_text = "@Jags123456 Bharat band on 28??<ed><U+00A0><U+00BD><ed><U+00B8><U+0082>Those who  are protesting #demonetization  are all different party leaders"
new_text = remove_symbols(sample_text)
print(new_text)
# Out:
# @Jags123456 Bharat band on 28??<ed><U+00A0><U+00BD><ed><U+00B8>Those who  are protesting #demonetization  are all different party leaders

# %% [markdown]
# Write a python program to extract dates from the text stored in the text file.
# Sample Text: Ron was born on 12-09-1992 and he was admitted to school 15-12-1999.
# Note- Store this sample text in the file and then extract dates.

# %%
import re

# %%
def extract_dates_from_file(file_path):
    with open(http://localhost:8888/edit/FlipRobo%20Assignment/sample_text.txt, 'r') as file:
    text = file.read()
    dates = re.findall(r'\b\d{2}-\d{4}\b', text)
    return dates
# Out:
#   Cell In[7], line 2
#     with open(http://localhost:8888/edit/FlipRobo%20Assignment/sample_text.txt, 'r') as file:
#                                                    ^
# SyntaxError: invalid decimal literal

# %% [markdown]
# unable to resolve

# %% [markdown]
# Create a function in python to remove all words from a string of length between 2 and 4.
# The use of the re.compile() method is mandatory.
# Sample Text: "The following example creates an ArrayList with a capacity of 50 elements. 4 elements are then added to the ArrayList and the ArrayList is trimmed accordingly."
# Expected Output:  following example creates ArrayList a capacity elements. 4 elements added ArrayList ArrayList trimmed accordingly.

# %%
import re

# %%
def remove_words(text):
    pattern = re.compile(r'\b\w{2,4}\b')
    return pattern.sub('', text)

# %%
sample_text = "The following example creates an ArrayList with a capacity of 50 elements. 4 elements are then added to the ArrayList and the ArrayList is trimmed accordingly."
output = remove_words(sample_text)
print(output)
# Out:
#  following example creates  ArrayList  a capacity   elements. 4 elements   added   ArrayList   ArrayList  trimmed accordingly.
